# %% [markdown]
# <a href="https://colab.research.google.com/github/Iftanaada/KKA-X.2-SEMESTER-1-IFTAHUNNADA/blob/main/Salinan_dari_Tipe_Variabel_Iftahun_Nada_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Iftahun Nada
#
# Kelas:X.2
#
# No.Absen:13

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("iftahunnada.2025@gmail.com")
print("iftahunnada.2025@gmail.com")
print("iftahunnada.2025@gmail.com")
# Out:
# iftahunnada.2025@gmail.com
# iftahunnada.2025@gmail.com
# iftahunnada.2025@gmail.com

# %%
email_user = "iftahunnada.2025@gmail.com"
print(email_user)
print(email_user)
print(email_user)
# Out:
# iftahunnada.2025@gmail.com
# iftahunnada.2025@gmail.com
# iftahunnada.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#Hanya boleh menggunakan huruf, angka, dan underscore
harga telur = 15000
print(harga telur)
# Out:
#   File "/tmp/ipython-input-1085076468.py", line 2
#     harga telur = 15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur = 15000
print(hargatelur)
# Out:
# 15000

# %%
#Tidak boleh diawali oleh angka
1_nama_siswa = "Ahmad Dhani"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-2404705053.py", line 2
#     1_nama_siswa = "Ahmad Dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci python
if = "Handayani"
print(if)
# Out:
#   File "/tmp/ipython-input-3203481015.py", line 2
#     if = "Handayani"
#        ^
# SyntaxError: invalid syntax

# %%
If = "Handayani"
print(If)
# Out:
# Handayani

# %%
print = "Noor"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2451231669.py in <cell line: 0>()
#       1 print = "Noor"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Noor"
print(Print)
# Out:
# Noor

# %%
#Sensitif dalam penulisan kapital
USIA = 17

print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3966167340.py in <cell line: 0>()
#       2 USIA = 17
#       3
# ----> 4 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_ = "Fazel Wardana"

# %%
_ = "Lia Wati"

# %%
print(_)
# Out:
# Lia Wati

# %% [markdown]
# #Operator Perbandingan

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8>10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7<=1 or 2!=2)
# Out:
# False

# %%
print(not(0==1 and 1!=1))
# Out:
# True

# %%
print(not(5<10 or 5<=10))
# Out:
# False
